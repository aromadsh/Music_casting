# %%
import os
import shutil
from tqdm import tqdm
import pandas as pd

# %%
a = os.listdir('./mp3')
print(len(a))
a
# Out:
# 362
# ['0_god.mp3',
#  '11 (Prod. 다이나믹듀오)-Wanna One(워너원) - 남바완.mp3',
#  '134-14-god.mp3',
#  '14 Round (feat. Egobomb & 쿼츠)_MC 스나이퍼.mp3',
#  '187 (feat. 임성현)_BILL STAX(빌스택스).mp3',
#  '1999년-god.mp3',
#  '2005년-god.mp3',
#  '21C 우리의 희망-god.mp3',
#  '9UCCI BANK (Feat. Dok2)_비와이.mp3',
#  'Arirang-숀 (SHAUN).mp3',
#  'BE I_B.I.mp3',
#  'Best Of Me_방탄소년단.mp3',
#  'bestdriverZ (Feat. Zion.T DEAN)_행주.mp3',
#  'Beverly 1lls_슈퍼비 & MyunDo.mp3',
#  'Bichael Yackson_비와이.mp3',
#  'Birthday (Feat. 박재범 Dok2)_Ja Mezz.mp3',
#  'Blue_볼빨간사춘기.mp3',
#  'Change-god.mp3',
#  'CHILLAX-TWICE(트와이스).mp3',
#  'Cookie-윤미래.mp3',
#  'Curtain call_비와이.mp3',
#  'Dance All Night-god.mp3',
#  'Dance The Night Away-TWICE(트와이스).mp3',
#  'Day Day (Feat. 박재범) (Prod. by GRAY)_비와이.mp3',
#  'Dejavu-뉴이스트 W.mp3',
#  'Elope-안예은.mp3',
#  'Euphoria-방탄소년단.mp3',
#  'Everything_10cm.mp3',
#  'Exit, 20th Century  Enter The 21st... (Intro)-god.mp3',
#  'Eyes On Me (Feat. G.Soul Dok2)_Junoflo.mp3',
#  'Fall In Love_케이윌.mp3',
# ...

# %%
for i in tqdm(range(len(a))):
    if '_' in a[i]:
        shutil.move('./mp3/'+a[i], './final_data/' + a[i])
    else : 
        pass
# Out:
#   0%|▏                                                                                | 1/362 [00:00<00:00, 485.23it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\ms\lib\shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: './mp3/11 (Prod. 다이나믹듀오)_Wanna One(워너원) _ 남바완.mp3' -> './final_data/11 (Prod. 다이나믹듀오)_Wanna One(워너원) _ 남바완.mp3'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6536\1606986957.py in <module>
#       1 for i in tqdm(range(len(a))):
#       2     if '_' in a[i]:
# ----> 3         shutil.move('./mp3/'+a[i], './final_data/' + a[i])
#       4     else :
# ...
