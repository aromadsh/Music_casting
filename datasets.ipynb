# %%
import tarfile
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# # fname = './arena_mel_0.tar'
# # ap = tarfile.open(fname)

# # ap.extractall('./all_image')
# # ap.close
# 0, 1000 / 1000, 2000 / 2000, 3000

# %%
for i in range(0, 1):
    for j in tqdm(range(0, 100)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:02<00:00,  3.63s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(100, 200)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:02<00:00,  3.62s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(200, 300)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:16<00:00,  3.76s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(300, 400)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:19<00:00,  3.79s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(400, 500)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:15<00:00,  3.75s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(500, 600)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:17<00:00,  3.78s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(600, 700)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:17<00:00,  3.78s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(700, 800)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:17<00:00,  3.77s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(800, 900)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:11<00:00,  3.72s/it]

# %%
for i in range(0, 1):
    for j in tqdm(range(900, 1000)):
        mel = np.load(f"./all_image/arena_mel/{i}/{j}.npy")
        librosa.display.specshow(mel)
        plt.savefig(f"./mel_image/{j}.png", dpi=200, bbox_inches='tight', pad_inches=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:07<00:00,  3.68s/it]
